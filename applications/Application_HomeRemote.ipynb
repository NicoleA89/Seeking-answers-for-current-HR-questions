# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from collections import defaultdict

df = pd.read_csv("../input/survey_results_public.csv")
df.head()

# %% [markdown]
# # Company Size & Remote Work
# Business Question: What impact does the size of a company have on whether employees work remotely?
# Assumption: Smaller companies are more flexible and thus allow more home office.

# %%
# Get a first overview of the DataFrame and the relevant columns.

# Size of DataFrame
print(df.shape)

# Missing values for 'CompanySize' and 'HomeRemote'
print(np.sum(df['CompanySize'].isnull() == 1))
print(np.sum(df['HomeRemote'].isnull() == 1))

# Proportion of missing values for 'CompanySize' and 'HomeRemote'
print(df['CompanySize'].isnull().mean())
print(df['HomeRemote'].isnull().mean())

# %%
# Take a look at the answers for 'CompanySize'
df['CompanySize'].value_counts(dropna=False).reset_index()

# %%
# For the purpose of this task, ignore all answers that do not specify a company size

# Drop 'CompanySize' without answers
df_work = df.dropna(subset=['CompanySize'], axis=0)
df_work = df_work[df_work['CompanySize'] != "I don't know"]
df_work = df_work[df_work['CompanySize'] != "I prefer not to answer"]

df_work.shape

# %%
# Take a look at the answers for 'HomeRemote'
temp= df_work['HomeRemote'].value_counts(dropna=False).reset_index()

# %%
# Drop NaN and 'It's complicated'
df_work = df_work.dropna(subset=['HomeRemote'], axis=0)
df_work = df_work[df_work['HomeRemote'] != "It's complicated"]
df_work.shape

# %%
#Now I would like to show the percentage of participants working Remote (all except 'Never') and not working remote (answer 'Never') and group by the CompanySize

# convert the string to integer to be able to calculate
remote_workers_values = temp['HomeRemote']
workers_remote_data = temp['HomeRemote'].astype(int)

# Get the sum over all answers
sum_of_remotes = workers_remote_data.sum()

# Create new column called 'Average'
remote_worker_table['Average'] = None

# Calculate average for each row in 'HomeRemote'
for i in range(len(remote_worker_table['HomeRemote'])):
    remote_worker_table['Average'][i] = (100 * remote_worker_table['HomeRemote'][i])/sum_of_remotes
